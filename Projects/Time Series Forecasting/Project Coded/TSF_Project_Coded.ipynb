# %% [markdown]
# ## **Context**
# As an analyst at ABC Estate Wines, we are presented with historical data encompassing the sales of different types of wines throughout the 20th century. These datasets originate from the same company but represent sales figures for distinct wine varieties. Our objective is to delve into the data, analyze trends, patterns, and factors influencing wine sales over the course of the century. By leveraging data analytics and forecasting techniques, we aim to gain actionable insights that can inform strategic decision-making and optimize sales strategies for the future
#
# ## **Objective**
# The primary objective of this project is to analyze and forecast wine sales trends for the 20th century based on historical data provided by ABC Estate Wines. We aim to equip ABC Estate Wines with the necessary insights and foresight to enhance sales performance, capitalize on emerging market opportunities, and maintain a competitive edge in the wine industry..

# %% [markdown]
# ### Import the necessary libraries.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels
import sklearn

# %% [markdown]
# ### Reading the dataset in a Time Series with proper Time frequency.

# %%
df_spark = pd.read_csv('Sparkling.csv',parse_dates=['YearMonth'],index_col='YearMonth')
df_spark.head()

# %%
df_spark.shape

# %%
df_rose = pd.read_csv('Rose.csv',parse_dates=['YearMonth'],index_col='YearMonth')
df_rose.head()

# %%
df_rose.shape

# %%
# Perform a left merge on YearMonth
combined_df = pd.merge(df_spark, df_rose, on="YearMonth", how="left", suffixes=("_Sparkling", "_Rose"))
combined_df

# %%
# copying data to another variable to avoid any changes to original data
data = combined_df.copy()

# %%
data.shape

# %% [markdown]
# ### Checking the data types of the columns for the dataset.

# %%
data.info()

# %% [markdown]
# ### Checking for missing values

# %%
# checking for null values
data.isnull().sum()

# %%
data.isnull().sum()

# %% [markdown]
# ### Checking for Duplicates

# %%
data.duplicated().sum()

# %%
data.describe(include="all").T

# %%
# Filter only 1994 data
data_1994 = data[data.index.year == 1994]
data_1994

# %%
# Apply spline interpolation to the Rose column
data_1994["Rose"] = data_1994["Rose"].interpolate(method="spline", order=1)

# %%
# Merge back with original dataset
data.update(data_1994)

# %%
data.isnull().sum()

# %%
data.describe(include="all").T

# %% [markdown]
# ### Plot the Time Series Data.

# %%
from pylab import rcParams

# %%
rcParams['figure.figsize'] = 15,8

# %%
data.plot();
plt.grid()

# %% [markdown]
# ### Plot a boxplot to understand the variation of Sparkling wine Sales to months across years.

# %%
sns.boxplot(x=data.index.month,y=data['Sparkling'])
plt.grid();

# %% [markdown]
# ### Plot a boxplot to understand the variation of Rose wine Sales to months across years.

# %%
sns.boxplot(x=data.index.month,y=data['Rose'])
plt.grid();

# %% [markdown]
# ### Plot a boxplot to understand the variation of Sparkling wine Sales to Years across years

# %%
sns.boxplot(x=data.index.year,y=data['Sparkling'])
plt.grid();

# %% [markdown]
# ### Plot a boxplot to understand the variation of Rose wine Sales to Years across years

# %%
sns.boxplot(x=data.index.year,y=data['Rose'])
plt.grid();

# %% [markdown]
# ### Plot a graph of monthly Sparkling wine Sales across years.

# %%
monthly_Sparkling_across_years = pd.pivot_table(data, values = 'Sparkling', columns = data.index.month_name(), index = data.index.year)
monthly_Sparkling_across_years

# %%
monthly_Sparkling_across_years.plot()
plt.grid()
plt.legend(loc='best');

# %% [markdown]
# ### Plot a graph of monthly Rose wine Sales across years.

# %%
monthly_Rose_across_years = pd.pivot_table(data, values = 'Rose', columns = data.index.month_name(), index = data.index.year)
monthly_Rose_across_years

# %%
monthly_Rose_across_years.plot()
plt.grid()
plt.legend(loc='best');

# %%
monthly_Rose_across_years = pd.pivot_table(data, values = 'Rose', columns = data.index.month_name(), index = data.index.year)
monthly_Rose_across_years

# %% [markdown]
# ### Plot a time series monthplot to understand the spread of Sparkling Wine Sales across different years and within different months across years.

# %%
from statsmodels.graphics.tsaplots import month_plot

month_plot(data['Sparkling'],ylabel='Sparkling Wine Sales')
plt.grid();

# %% [markdown]
# ### Plot a time series monthplot to understand the spread of Rose Wine Sales across different years and within different months across years.

# %%
from statsmodels.graphics.tsaplots import month_plot

month_plot(data['Rose'],ylabel='Rose Wine Sales')
plt.grid();

# %% [markdown]
# ### Plot the Empirical Cumulative Distribution of Sprakling Wine Sales.

# %%
# statistics
from statsmodels.distributions.empirical_distribution import ECDF

plt.figure(figsize = (18, 8))
cdf = ECDF(data['Sparkling'])
plt.plot(cdf.x, cdf.y, label = "statmodels");
plt.grid()
plt.xlabel('Sprakling Wine Sales');
plt.ylabel('pct_of_sales');

# %% [markdown]
# ### Plot the Empirical Cumulative Distribution of Rose Wine Sales.

# %%
# statistics
from statsmodels.distributions.empirical_distribution import ECDF

plt.figure(figsize = (18, 8))
cdf = ECDF(data['Rose'])
plt.plot(cdf.x, cdf.y, label = "statmodels");
plt.grid()
plt.xlabel('Rose Wine Sales');
plt.ylabel('pct_of_sales');

# %% [markdown]
# ### Plot a graph of the average and percentage change of Sales of Sparkline wine across years

# %%
# group by date and get average Customers, and precent change
average_Sparkling_sales    = data.groupby(data.index)["Sparkling"].mean()
pct_change_in_sales = data.groupby(data.index)["Sparkling"].sum().pct_change()

fig, (axis1,axis2) = plt.subplots(2,1,sharex=True,figsize=(15,8))

# plot average Sales over time(year-month)
ax1 = average_Sparkling_sales.plot(legend=True,ax=axis1,marker='o',title="average_Sparkling_sales")

ax1.set_xticks(range(len(average_Sparkling_sales)))
ax1.set_xticklabels(average_Sparkling_sales.index.tolist(), rotation=90)

# plot precent change for Sales over time(year-month)
ax2 = pct_change_in_sales.plot(legend=True,ax=axis2,marker='o',rot=90,colormap="summer",title="pct_change_in_sales")

# %% [markdown]
# ### Plot a graph of the average and percentage change of Sales of Sparkline wine across years

# %%
# group by date and get average Customers, and precent change
average_Rose_sales    = data.groupby(data.index)["Rose"].mean()
pct_change_in_sales = data.groupby(data.index)["Rose"].sum().pct_change()

fig, (axis1,axis2) = plt.subplots(2,1,sharex=True,figsize=(15,8))

# plot average Sales over time(year-month)
ax1 = average_Rose_sales.plot(legend=True,ax=axis1,marker='o',title="average_Rose_sales")

ax1.set_xticks(range(len(average_Rose_sales)))
ax1.set_xticklabels(average_Rose_sales.index.tolist(), rotation=90)

# plot precent change for Sales over time(year-month)
ax2 = pct_change_in_sales.plot(legend=True,ax=axis2,marker='o',rot=90,colormap="summer",title="pct_change_in_sales")

# %% [markdown]
# ### Decompose the Time Series to understand the various components. (Sparkling Wine)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(data['Sparkling'],model='additive')
decomposition.plot();

# %% [markdown]
# ### From the plot We can see that alot of residuals are situated around 0
#
# ### Let's check for Multiplicative Decompostion

# %%
decomposition = seasonal_decompose(data['Sparkling'],model='multiplicative')
decomposition.plot();

# %% [markdown]
# ### For the multiplicative series, we see that a lot of residuals are located around 1. Thus, Multiplicative Decomposition is the right way to decompose the time series

# %% [markdown]
# ### Decompose the Time Series to understand the various components. (Rose Wine)

# %%
decomposition = seasonal_decompose(data['Rose'],model='additive')
decomposition.plot();

# %% [markdown]
# ### From the plot We can see that alot of residuals are situated around 0
#
# ### Let's check for Multiplicative Decompostion

# %%
decomposition = seasonal_decompose(data['Rose'],model='multiplicative')
decomposition.plot();

# %% [markdown]
# ### For the multiplicative series, we see that a lot of residuals are located around 1. Thus, Multiplicative Decomposition is the right way to decompose the time series

# %% [markdown]
# ### Checking for stationarity of the whole Time Series data. (Sparkling Wine)

# %%
## Test for stationarity of the series - Dicky Fuller test

from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=7).mean() #determining the rolling mean
    rolstd = timeseries.rolling(window=7).std()   #determining the rolling standard deviation

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput,'\n')

# %%
test_stationarity(data['Sparkling'])

# %% [markdown]
# ### We see that at p-value is greater than alpha value which is 0.05 or 5% significant level, This tells this Time Series is non-stationary.

# %% [markdown]
# ### Let us take a difference of order 1 and check whether the Time Series is stationary or not.

# %%
test_stationarity(data['Sparkling'].diff().dropna())

# %% [markdown]
# ### We see that at $\alpha$ = 0.05 the Time Series is indeed stationary.

# %% [markdown]
# ### Checking for stationarity of the whole Time Series data. (Rose Wine)

# %%
test_stationarity(data['Rose'])

# %% [markdown]
# ### We see that at p-value is greater than alpha value which is 0.05 or 5% significant level, This tells this Time Series is non-stationary.

# %% [markdown]
# ### Let us take a difference of order 1 and check whether the Time Series is stationary or not.

# %%
test_stationarity(data['Rose'].diff().dropna())

# %% [markdown]
# ### We see that at $\alpha$ = 0.05 the Time Series is indeed stationary.

# %% [markdown]
# ### Ploting the Autocorrelation function plots on the Sparkling wine  data.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(data['Sparkling'],lags=50)
plot_acf(data['Sparkling'].diff().dropna(),lags=50,title='Differenced Data Autocorrelation')
plt.show()

# %% [markdown]
# ### Ploting the Autocorrelation function plots on the Rose wine  data.

# %%
plot_acf(data['Rose'],lags=50)
plot_acf(data['Rose'].diff().dropna(),lags=50,title='Differenced Data Autocorrelation')
plt.show()

# %% [markdown]
# ### From the above plots, we can say that there seems to be a seasonality in the data.

# %% [markdown]
# ## Split the data into train and test and plot the training and test data.
#
# Training Data is till the end of 1990. Test Data is from the beginning of 1991 to the last time stamp provided.

# %%
train=data[data.index.year <= 1990]
test=data[data.index.year > 1990]

# %%
print(train.shape)
print(test.shape)

# %%
print(train.head(),'\n')
print(train.tail(),'\n\n')
print(test.head(),'\n')
print(test.tail(),'\n')

# %% [markdown]
# ### Testing the training data for stationarity using the Augmented Dickey-Fuller (ADF) test at $\alpha$ = 0.05.
# ### Training Data stationarity for Sparkling Wine Sales

# %%
## Test for stationarity of the series - Dicky Fuller test

from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=7).mean()
    rolstd = timeseries.rolling(window=7).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput,'\n')

# %%
test_stationarity(train['Sparkling'])

# %% [markdown]
# ### We see that the series is not stationary at $\alpha$ = 0.05.

# %%
test_stationarity(train['Sparkling'].diff().dropna())

# %% [markdown]
# ### We see that after taking a difference of order 1 the series have become stationary at $\alpha$ = 0.05.

# %% [markdown]
# ### Testing the training data for stationarity using the Augmented Dickey-Fuller (ADF) test at $\alpha$ = 0.05.
# ### Training Data stationarity for Rose Wine Sales

# %%
test_stationarity(train['Rose'])

# %% [markdown]
# ### We see that the series is not stationary at $\alpha$ = 0.05.

# %%
test_stationarity(train['Rose'].diff().dropna())

# %% [markdown]
# ### We see that after taking a difference of order 1 the series have become stationary at $\alpha$ = 0.05.

# %%
train.info()

# %% [markdown]
# ## Building an Automated version of an <font color='blue'>ARMA model</font> for which the best parameters are selected in accordance with the lowest Akaike Information Criteria (AIC).

# %%
import itertools
p = q = range(0, 3)
d= range(1)
pdq = list(itertools.product(p, d, q))
print('Some parameter combinations for the Model...')
for i in range(1,len(pdq)):
    print('Model: {}'.format(pdq[i]))

# %%
# Creating an empty Dataframe with column names only
ARMA_AIC_Sparkling = pd.DataFrame(columns=['param', 'AIC'])
ARMA_AIC_Sparkling

# %% [markdown]
# ### Sparkling Wine Sales Model

# %%
from statsmodels.tsa.arima.model import ARIMA

for param in pdq:
    ARMA_model = ARIMA(train['Sparkling'].values,order=param).fit()
    print('ARIMA{} - AIC:{}'.format(param,ARMA_model.aic))
    
    # Convert new row into a DataFrame before concatenation
    new_row = pd.DataFrame({'param': [param], 'AIC': [ARMA_model.aic]})
    ARMA_AIC_Sparkling = pd.concat([ARMA_AIC_Sparkling, new_row], ignore_index=True)

# %%
## Sort the above AIC values in the ascending order to get the parameters for the minimum AIC value

ARMA_AIC_Sparkling.sort_values(by='AIC',ascending=True)

# %%
auto_ARIMA_Sparkling = ARIMA(train['Sparkling'], order=(2,0,1))

results_auto_ARIMA_Sparkling = auto_ARIMA_Sparkling.fit()

print(results_auto_ARIMA_Sparkling.summary())

# %% [markdown]
# ### Predicting on the Test of Sparkling wine Set using this model and evaluate the model.

# %%
predicted_auto_ARIMA_Sparkling = results_auto_ARIMA_Sparkling.forecast(steps=len(test))

# %%
from sklearn.metrics import  mean_squared_error
rmse = mean_squared_error(test['Sparkling'],predicted_auto_ARIMA_Sparkling ,squared=False)
print(rmse)

# %%
resultsDf_Sparkling = pd.DataFrame({'RMSE': [rmse]}
                           ,index=['ARMA(2,0,1)'])

resultsDf_Sparkling

# %% [markdown]
# ### Rose Wine Sales Model

# %%
# Creating an empty Dataframe with column names only
ARMA_AIC_Rose = pd.DataFrame(columns=['param', 'AIC'])
ARMA_AIC_Rose

# %%
from statsmodels.tsa.arima.model import ARIMA

for param in pdq:
    ARMA_model = ARIMA(train['Rose'].values,order=param).fit()
    print('ARIMA{} - AIC:{}'.format(param,ARMA_model.aic))
    
    new_row = pd.DataFrame({'param': [param], 'AIC': [ARMA_model.aic]})
    ARMA_AIC_Rose = pd.concat([ARMA_AIC_Rose, new_row], ignore_index=True)

# %%
## Sort the above AIC values in the ascending order to get the parameters for the minimum AIC value

ARMA_AIC_Rose.sort_values(by='AIC',ascending=True)

# %%
auto_ARIMA_Rose = ARIMA(train['Sparkling'], order=(1,0,2))

results_auto_ARIMA_Rose = auto_ARIMA_Rose.fit()

print(results_auto_ARIMA_Rose.summary())

# %% [markdown]
# ### Predicting on the Test of Rose wine Set using this model and evaluate the model.

# %%
predicted_auto_ARIMA_Rose = results_auto_ARIMA_Rose.forecast(steps=len(test))

# %%
from sklearn.metrics import  mean_squared_error
rmse = mean_squared_error(test['Rose'],predicted_auto_ARIMA_Rose,squared=False)
print(rmse)

# %%
resultsDf_Rose = pd.DataFrame({'RMSE': [rmse]}
                           ,index=['ARMA(1,0,2)'])
resultsDf_Rose

# %% [markdown]
# ## Building an Automated version of an <font color='blue'>ARIMA model</font> for which the best parameters are selected in accordance with the lowest Akaike Information Criteria (AIC).

# %%
import itertools
p = q = range(0, 3)
d= range(1,2)
pdq = list(itertools.product(p, d, q))
print('Some parameter combinations for the Model...')
for i in range(1,len(pdq)):
    print('Model: {}'.format(pdq[i]))

# %%
# Creating an empty Dataframe with column names only
ARIMA_AIC_Sparkling = pd.DataFrame(columns=['param', 'AIC'])
ARIMA_AIC_Sparkling

# %% [markdown]
# ### Sparkling Wine Sales ARIMA Model

# %%
from statsmodels.tsa.arima.model import ARIMA

for param in pdq:
    ARIMA_model = ARIMA(train['Sparkling'].values,order=param).fit()
    print('ARIMA{} - AIC:{}'.format(param,ARIMA_model.aic))
    
    new_row = pd.DataFrame({'param': [param], 'AIC': [ARIMA_model.aic]})
    ARIMA_AIC_Sparkling = pd.concat([ARIMA_AIC_Sparkling, new_row], ignore_index=True)

# %%
## Sort the above AIC values in the ascending order to get the parameters for the minimum AIC value

ARIMA_AIC_Sparkling.sort_values(by='AIC',ascending=True)

# %%
auto_ARIMA_Sparkling = ARIMA(train['Sparkling'], order=(2,1,2))

results_auto_ARIMA_Sparkling = auto_ARIMA_Sparkling.fit()

print(results_auto_ARIMA_Sparkling.summary())

# %% [markdown]
# ### Predicting on the Test Set using this model and evaluate the model.

# %%
predicted_auto_ARIMA_Sparkling = results_auto_ARIMA_Sparkling.forecast(steps=len(test))

# %%
from sklearn.metrics import  mean_squared_error
rmse = mean_squared_error(test['Sparkling'],predicted_auto_ARIMA_Sparkling,squared=False)
print(rmse)

# %%
temp_resultsDf0 = pd.DataFrame({'RMSE': [rmse]}
                           ,index=['ARIMA(2,1,2)'])


resultsDf_Sparkling = pd.concat([resultsDf_Sparkling,temp_resultsDf0])
resultsDf_Sparkling

# %% [markdown]
# ### Rose Wine Sales ARIMA Model

# %%
# Creating an empty Dataframe with column names only
ARIMA_AIC_Rose = pd.DataFrame(columns=['param', 'AIC'])
ARIMA_AIC_Rose

# %%
from statsmodels.tsa.arima.model import ARIMA

for param in pdq:
    ARIMA_model = ARIMA(train['Rose'].values,order=param).fit()
    print('ARIMA{} - AIC:{}'.format(param,ARIMA_model.aic))
    
    new_row = pd.DataFrame({'param': [param], 'AIC': [ARIMA_model.aic]})
    ARIMA_AIC_Rose = pd.concat([ARIMA_AIC_Rose, new_row], ignore_index=True)

# %%
## Sort the above AIC values in the ascending order to get the parameters for the minimum AIC value

ARIMA_AIC_Rose.sort_values(by='AIC',ascending=True)

# %%
auto_ARIMA_Rose = ARIMA(train['Sparkling'], order=(0,1,2))

results_auto_ARIMA_Rose = auto_ARIMA_Rose.fit()

print(results_auto_ARIMA_Rose.summary())

# %% [markdown]
# ### Predicting on the Test Set using this model and evaluate the model.

# %%
predicted_auto_ARIMA_Rose = results_auto_ARIMA_Rose.forecast(steps=len(test))

# %%
from sklearn.metrics import  mean_squared_error
rmse = mean_squared_error(test['Rose'],predicted_auto_ARIMA_Rose,squared=False)
print(rmse)

# %%
temp_resultsDf0 = pd.DataFrame({'RMSE': [rmse]}
                           ,index=['ARIMA(0,1,2)'])


resultsDf_Rose = pd.concat([resultsDf_Rose,temp_resultsDf0])
resultsDf_Rose

# %% [markdown]
# ### Building an Automated version of a <font color='blue'>SARIMA</font> model for which the best parameters are selected in accordance with the lowest Akaike Information Criteria (AIC).

# %% [markdown]
# ### SARIMA Model for Sparkling Wine Sales

# %%
plot_acf(data['Sparkling'].diff().dropna(),lags=50,title='Differenced Data Autocorrelation')
plt.show()

# %% [markdown]
# #### We see that there can be a seasonality of 6 for Sparkling Wine Sales. But from the decompostion at the start we ascertained that visually it looks like the seasonality =6 and thus using the same

# %% [markdown]
# ### Setting the seasonality as 6  to estimate parametrs using auto SARIMA model.

# %%
import itertools
p = q = range(0, 3)
d= range(1,2)
D = range(0,1)
pdq = list(itertools.product(p, d, q))
model_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, D, q))]
print('Examples of some parameter combinations for Model...')
for i in range(1,len(pdq)):
    print('Model: {}{}'.format(pdq[i], model_pdq[i]))

# %%
SARIMA_AIC_Sparkling = pd.DataFrame(columns=['param','seasonal', 'AIC'])
SARIMA_AIC_Sparkling

# %%
import statsmodels.api as sm

for param in pdq:
    for param_seasonal in model_pdq:
        SARIMA_model = sm.tsa.statespace.SARIMAX(train['Sparkling'].values,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            
        results_SARIMA = SARIMA_model.fit(maxiter=1000)
        print('SARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results_SARIMA.aic))

        new_row = pd.DataFrame({'param':[param],'seasonal':[param_seasonal] ,'AIC': results_SARIMA.aic})
        SARIMA_AIC_Sparkling = pd.concat([SARIMA_AIC_Sparkling, new_row], ignore_index=True)

# %%
SARIMA_AIC_Sparkling.sort_values(by=['AIC']).head()

# %%
import statsmodels.api as sm

auto_SARIMA_12 = sm.tsa.statespace.SARIMAX(train['Sparkling'].values,
                                order=(1, 1, 2),
                                seasonal_order=(1, 0, 2, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_auto_SARIMA_12 = auto_SARIMA_12.fit(maxiter=1000)
print(results_auto_SARIMA_12.summary())

# %%
results_auto_SARIMA_12.plot_diagnostics()
plt.show()

# %% [markdown]
# ### From the model diagnostics plot, we can see that all the individual diagnostics plots almost follow the theoretical numbers and thus we cannot develop any pattern from these plots.

# %% [markdown]
# ### Predict on the Test Set using this model and evaluate the model.

# %%
predicted_auto_SARIMA_12 = results_auto_SARIMA_12.get_forecast(steps=len(test))

# %%
predicted_auto_SARIMA_12.summary_frame(alpha=0.05).head()

# %%
rmse = mean_squared_error(test['Sparkling'],predicted_auto_SARIMA_12.predicted_mean,squared=False)
print(rmse)

# %%
temp_resultsDf = pd.DataFrame({'RMSE': [rmse]}
                           ,index=['SARIMA(1, 1, 2)(1,0,2,12)'])


resultsDf_Sparkling = pd.concat([resultsDf_Sparkling,temp_resultsDf])

resultsDf_Sparkling

# %% [markdown]
# ### SARIMA Model for Rose Wine Sales

# %%
plot_acf(data['Rose'].diff().dropna(),lags=50,title='Differenced Data Autocorrelation')
plt.show()

# %% [markdown]
# #### We see that there can be a seasonality of 6 for Sparkling Wine Sales. But from the decompostion at the start we ascertained that visually it looks like the seasonality =6 and thus using the same

# %% [markdown]
# ### Setting the seasonality as 6 to estimate parametrs using auto SARIMA model.

# %%
import itertools
p = q = range(0, 3)
d= range(1,2)
D = range(0,1)
pdq = list(itertools.product(p, d, q))
model_pdq = [(x[0], x[1], x[2], 6) for x in list(itertools.product(p, D, q))]
print('Examples of some parameter combinations for Model...')
for i in range(1,len(pdq)):
    print('Model: {}{}'.format(pdq[i], model_pdq[i]))

# %%
SARIMA_AIC_Rose = pd.DataFrame(columns=['param','seasonal', 'AIC'])
SARIMA_AIC_Rose

# %%
import statsmodels.api as sm

for param in pdq:
    for param_seasonal in model_pdq:
        SARIMA_model = sm.tsa.statespace.SARIMAX(train['Rose'].values,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            
        results_SARIMA = SARIMA_model.fit(maxiter=1000)
        print('SARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results_SARIMA.aic))

        new_row = pd.DataFrame({'param':[param],'seasonal':[param_seasonal] ,'AIC': results_SARIMA.aic})
        SARIMA_AIC_Rose = pd.concat([SARIMA_AIC_Rose, new_row], ignore_index=True)

# %%
SARIMA_AIC_Rose.sort_values(by=['AIC']).head()

# %%
import statsmodels.api as sm

auto_SARIMA_6 = sm.tsa.statespace.SARIMAX(train['Rose'].values,
                                order=(1, 1, 2),
                                seasonal_order=(2, 0, 2, 6),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_auto_SARIMA_6 = auto_SARIMA_6.fit(maxiter=1000)
print(results_auto_SARIMA_6.summary())

# %%
results_auto_SARIMA_6.plot_diagnostics()
plt.show()

# %% [markdown]
# ### From the model diagnostics plot, we can see that all the individual diagnostics plots almost follow the theoretical numbers and thus we cannot develop any pattern from these plots.

# %% [markdown]
# ### Predict on the Test Set using this model and evaluate the model.

# %%
predicted_auto_SARIMA_6 = results_auto_SARIMA_6.get_forecast(steps=len(test))

# %%
predicted_auto_SARIMA_6.summary_frame(alpha=0.05).head()

# %%
rmse = mean_squared_error(test['Rose'],predicted_auto_SARIMA_6.predicted_mean,squared=False)
print(rmse)

# %%
temp_resultsDf = pd.DataFrame({'RMSE': [rmse]}
                           ,index=['SARIMA(1, 1, 2)(2,0,2,6)'])


resultsDf_Rose = pd.concat([resultsDf_Rose,temp_resultsDf])

resultsDf_Rose

# %% [markdown]
# ## Building the most optimum model on the Sparkling Wine Full Data.

# %%
full_data_model_sparkling = sm.tsa.statespace.SARIMAX(data['Sparkling'],
                                order=(1,1,2),
                                seasonal_order=(1, 0, 2, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_full_data_model_sparkling = full_data_model_sparkling.fit(maxiter=1000)
print(results_full_data_model_sparkling.summary())

# %%
results_full_data_model_sparkling.plot_diagnostics();

# %% [markdown]
# ## Evaluate the Sparkling Wine model on the whole and predict Entire 20th Century i.e., unitil 1999-12-01 into the future

# %%
predicted_manual_SARIMA_12_full_data_Sparkling = results_full_data_model_sparkling.get_forecast(steps=101)

# %%
predicted_manual_SARIMA_12_full_data_Sparkling.summary_frame(alpha=0.05).head()

# %%
rmse = mean_squared_error(data['Sparkling'],results_full_data_model_sparkling.fittedvalues,squared=False)
print('RMSE of the Full Model',rmse)

# %%
pred_full_manual_SARIMA_date = predicted_manual_SARIMA_12_full_data_Sparkling.summary_frame(alpha=0.05).set_index(pd.date_range(start='1991-08-01',end='2000-01-01', freq='M'))

# %%
# plot the forecast along with the confidence band

axis = data['Sparkling'].plot(label='Observed')
pred_full_manual_SARIMA_date['mean'].plot(ax=axis, label='Forecast', alpha=0.7)
axis.fill_between(pred_full_manual_SARIMA_date.index, pred_full_manual_SARIMA_date['mean_ci_lower'], 
                  pred_full_manual_SARIMA_date['mean_ci_upper'], color='k', alpha=.15)
axis.set_xlabel('YearMonth')
axis.set_ylabel('Sparkling')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Building the most optimum model on the Rose Wine Full Data.

# %%
full_data_model_Rose= sm.tsa.statespace.SARIMAX(data['Rose'],
                                order=(1,1,2),
                                seasonal_order=(2, 0, 2, 6),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_full_data_model_Rose = full_data_model_Rose.fit(maxiter=1000)
print(results_full_data_model_Rose.summary())

# %%
results_full_data_model_Rose.plot_diagnostics();

# %% [markdown]
# ## Evaluate the Rose Wine model on the whole and predict Entire 20th Century i.e., unitil 1999-12-01 into the future

# %%
predicted_manual_SARIMA_6_full_data_Rose = results_full_data_model_Rose.get_forecast(steps=101)

# %%
predicted_manual_SARIMA_6_full_data_Rose.summary_frame(alpha=0.05).head()

# %%
rmse = mean_squared_error(data['Rose'],results_full_data_model_Rose.fittedvalues,squared=False)
print('RMSE of the Full Model',rmse)

# %%
pred_full_manual_SARIMA_date = predicted_manual_SARIMA_6_full_data_Rose.summary_frame(alpha=0.05).set_index(pd.date_range(start='1991-08-01',end='2000-01-01', freq='M'))

# %%
# plot the forecast along with the confidence band

axis = data['Rose'].plot(label='Observed')
pred_full_manual_SARIMA_date['mean'].plot(ax=axis, label='Forecast', alpha=0.7)
axis.fill_between(pred_full_manual_SARIMA_date.index, pred_full_manual_SARIMA_date['mean_ci_lower'], 
                  pred_full_manual_SARIMA_date['mean_ci_upper'], color='k', alpha=.15)
axis.set_xlabel('YearMonth')
axis.set_ylabel('Rose')
plt.legend(loc='best')
plt.show()
